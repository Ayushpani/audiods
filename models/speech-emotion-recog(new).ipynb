neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_wife_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_keen_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_cheek_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_keg_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_thought_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_soap_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_ditch_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_knock_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_five_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_should_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_chief_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_wag_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_when_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_gin_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_met_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_take_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_beg_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_bought_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_long_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_live_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_red_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_chair_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_ripe_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_hash_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_tip_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_late_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_peg_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_size_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_pole_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_make_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_burn_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_tool_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_mob_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_pool_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_loaf_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_thin_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_choice_neutral.wav
# /kaggle/input/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_neutral/YAF_wheat_neutral.wav
# ...
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_chat_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_wheat_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_red_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_half_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_witch_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_chalk_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_said_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_raise_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_gun_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_lore_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_rough_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_rain_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_tool_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_seize_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_such_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_page_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_hire_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_five_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_door_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_neat_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_mode_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_keep_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_phone_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_death_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_room_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_bought_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_walk_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_chair_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_third_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_shack_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_young_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_gin_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_gap_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_gas_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_far_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_chain_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_tell_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_mob_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_white_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_sheep_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_learn_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_pad_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_bean_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_whip_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_sub_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_hole_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_time_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_bone_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_have_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_soup_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_chief_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_back_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_dab_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_numb_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_vine_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_fat_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_kill_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_wife_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_dead_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_tire_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_jug_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_base_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_talk_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_good_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_size_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_beg_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_haze_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_raid_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_dip_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_boat_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_choice_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_bite_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_tough_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_pool_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_tape_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_cab_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_pass_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_goose_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_shall_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_thought_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_near_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_ripe_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_yearn_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_hall_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_sure_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_when_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_shout_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_south_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_get_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_check_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_book_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_reach_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_nice_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_jail_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_thumb_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_hash_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_turn_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_lot_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_thin_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_food_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_date_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_gaze_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_tip_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_sour_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_cheek_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_dodge_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_join_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_puff_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_pick_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_pearl_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_fall_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_match_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_deep_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_vote_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_make_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_road_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_fail_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_doll_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_mood_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_laud_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_nag_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_rush_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_lid_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_keg_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_peg_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_knock_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_team_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_ring_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_wash_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_luck_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_love_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_king_disgust.wav
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_disgust/YAF_met_disgust.wav

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
 #   for filename in filenames:
  #      print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Import Modules
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.models import load_model
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
len(paths)
paths[:5]
labels[:5]

## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
df['label'].value_counts()

# Exploratory Data Analysis
sns.countplot(data=df, x='label')
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

# Feature Extraction
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc
extract_mfcc(df['speech'][0])
x_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))
x_mfcc
X = [x for x in x_mfcc]
X = np.array(X)
X.shape
## input split
X = np.expand_dims(X, -1)
X.shape
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
Y = enc.fit_transform(df[['label']])
Y = Y.toarray()
Y.shape
# Create the LSTM Model
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Train the model
history = model.fit(X, Y, validation_split=0.2, epochs=50, batch_size=64)
# Plot the results
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# Save the model
model.save('models/lstm.h5')
# Out:
# Dataset is Loaded
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 35/35 [==============================] - 10s 184ms/step - loss: 1.0895 - accuracy: 0.5839 - val_loss: 2.7879 - val_accuracy: 0.0607
# Epoch 2/50
# 35/35 [==============================] - 7s 197ms/step - loss: 0.4298 - accuracy: 0.8397 - val_loss: 2.5399 - val_accuracy: 0.3143
# Epoch 3/50
# 35/35 [==============================] - 6s 163ms/step - loss: 0.2274 - accuracy: 0.9272 - val_loss: 1.5917 - val_accuracy: 0.5339
# Epoch 4/50
# 35/35 [==============================] - 7s 188ms/step - loss: 0.1749 - accuracy: 0.9393 - val_loss: 2.0261 - val_accuracy: 0.5464
# Epoch 5/50
# 35/35 [==============================] - 5s 155ms/step - loss: 0.1517 - accuracy: 0.9531 - val_loss: 2.0072 - val_accuracy: 0.6000
# Epoch 6/50
# 35/35 [==============================] - 7s 190ms/step - loss: 0.1232 - accuracy: 0.9670 - val_loss: 1.6645 - val_accuracy: 0.6071
# Epoch 7/50
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0904 - accuracy: 0.9732 - val_loss: 1.8945 - val_accuracy: 0.6482
# Epoch 8/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.1430 - accuracy: 0.9603 - val_loss: 2.8714 - val_accuracy: 0.6232
# Epoch 9/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0722 - accuracy: 0.9772 - val_loss: 1.6972 - val_accuracy: 0.7071
# Epoch 10/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0762 - accuracy: 0.9759 - val_loss: 1.4046 - val_accuracy: 0.7000
# Epoch 11/50
# 35/35 [==============================] - 6s 156ms/step - loss: 0.0791 - accuracy: 0.9741 - val_loss: 2.0104 - val_accuracy: 0.6750
# Epoch 12/50
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0640 - accuracy: 0.9799 - val_loss: 2.5881 - val_accuracy: 0.6250
# Epoch 13/50
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0762 - accuracy: 0.9768 - val_loss: 1.7114 - val_accuracy: 0.6768
# Epoch 14/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0517 - accuracy: 0.9812 - val_loss: 1.6114 - val_accuracy: 0.7071
# Epoch 15/50
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0590 - accuracy: 0.9866 - val_loss: 1.7302 - val_accuracy: 0.6589
# Epoch 16/50
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0361 - accuracy: 0.9884 - val_loss: 1.8967 - val_accuracy: 0.6946
# Epoch 17/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0373 - accuracy: 0.9884 - val_loss: 1.6600 - val_accuracy: 0.7339
# Epoch 18/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0807 - accuracy: 0.9714 - val_loss: 2.1084 - val_accuracy: 0.6661
# Epoch 19/50
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0592 - accuracy: 0.9839 - val_loss: 2.1146 - val_accuracy: 0.6982
# Epoch 20/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0938 - accuracy: 0.9701 - val_loss: 2.7532 - val_accuracy: 0.6304
# Epoch 21/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0429 - accuracy: 0.9884 - val_loss: 2.3119 - val_accuracy: 0.6375
# Epoch 22/50
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0369 - accuracy: 0.9884 - val_loss: 2.9516 - val_accuracy: 0.6482
# Epoch 23/50
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0255 - accuracy: 0.9920 - val_loss: 3.2464 - val_accuracy: 0.6607
# Epoch 24/50
# 35/35 [==============================] - 6s 169ms/step - loss: 0.0188 - accuracy: 0.9933 - val_loss: 2.6769 - val_accuracy: 0.6929
# Epoch 25/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0285 - accuracy: 0.9924 - val_loss: 2.1005 - val_accuracy: 0.7357
# Epoch 26/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0165 - accuracy: 0.9933 - val_loss: 1.9058 - val_accuracy: 0.7000
# Epoch 27/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0310 - accuracy: 0.9893 - val_loss: 2.5852 - val_accuracy: 0.6946
# Epoch 28/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 1.6904 - val_accuracy: 0.7125
# Epoch 29/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 3.0646 - val_accuracy: 0.6589
# Epoch 30/50
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 3.0285 - val_accuracy: 0.6446
# Epoch 31/50
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 2.8366 - val_accuracy: 0.6464
# Epoch 32/50
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 3.1357 - val_accuracy: 0.6625
# Epoch 33/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 3.0593 - val_accuracy: 0.6536
# Epoch 34/50
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 3.9833 - val_accuracy: 0.6446
# Epoch 35/50
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0240 - accuracy: 0.9929 - val_loss: 3.2116 - val_accuracy: 0.6821
# Epoch 36/50
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0431 - accuracy: 0.9857 - val_loss: 3.4225 - val_accuracy: 0.6304
# Epoch 37/50
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 3.3978 - val_accuracy: 0.6179
# Epoch 38/50
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0408 - accuracy: 0.9879 - val_loss: 3.4214 - val_accuracy: 0.6482
# Epoch 39/50
# 35/35 [==============================] - 8s 225ms/step - loss: 0.0310 - accuracy: 0.9897 - val_loss: 1.9314 - val_accuracy: 0.7143
# Epoch 40/50
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0326 - accuracy: 0.9906 - val_loss: 2.7228 - val_accuracy: 0.6875
# Epoch 41/50
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0235 - accuracy: 0.9929 - val_loss: 2.6667 - val_accuracy: 0.6625
# Epoch 42/50
# 35/35 [==============================] - 5s 148ms/step - loss: 0.0096 - accuracy: 0.9978 - val_loss: 3.1215 - val_accuracy: 0.6607
# Epoch 43/50
# 35/35 [==============================] - 7s 192ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 3.6973 - val_accuracy: 0.6571
# Epoch 44/50
# 35/35 [==============================] - 5s 148ms/step - loss: 0.0345 - accuracy: 0.9897 - val_loss: 3.0116 - val_accuracy: 0.6304
# Epoch 45/50
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 2.8266 - val_accuracy: 0.6786
# Epoch 46/50
# 35/35 [==============================] - 6s 166ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 2.9384 - val_accuracy: 0.6518
# Epoch 47/50
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0398 - accuracy: 0.9902 - val_loss: 2.5487 - val_accuracy: 0.6250
# Epoch 48/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0213 - accuracy: 0.9929 - val_loss: 2.6827 - val_accuracy: 0.6554
# Epoch 49/50
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 3.4946 - val_accuracy: 0.6482
# Epoch 50/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0130 - accuracy: 0.9964 - val_loss: 3.1642 - val_accuracy: 0.6554

# %%
model.save('models/lstm.h5')
print("saved")
# Out:
# saved

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Specify the directory where the model is saved
model_directory = os.path.join(current_directory, 'models')

# List the contents of the model directory
model_files = os.listdir(model_directory)

# Print the contents
print("Contents of the model directory:")
for file in model_files:
    print(file)
# Out:
# Contents of the model directory:
# lstm.h5

# %%
from IPython.display import FileLink

# Provide the path to the file
file_path = 'models/lstm.h5'

# Create a download link for the file
FileLink(file_path)
# Out:
# /content/models/lstm.h5
